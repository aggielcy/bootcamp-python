# %%
from datetime import datetime, date, timedelta
from dateutil.relativedelta import relativedelta

# %%
print(datetime.now())
print(date.today())

birthday = date(2020,12,31)
print(birthday)

#add date
print (birthday + timedelta(days=10))
# Out:
# 2026-05-26 15:55:04.499928
# 2026-05-26
# 2020-12-31
# 2021-01-10

# %%
join_date = date.today()
probation_end_date = join_date + relativedelta (months=3) - relativedelta (days=1)
print(probation_end_date)

#year, months, days
print(type(join_date))
# Out:
# 2026-08-25
# <class 'datetime.date'>

# %%
formatted_date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

print(type(formatted_date))
print(formatted_date)

str_datetime = "2025/12/31 23:59:59"
special_datetime = datetime.strftime(str_datetime,"%Y/%m/%d %H:%M:%S")
print(type(special_datetime))
print(special_datetime)
# Out:
# <class 'str'>
# 2026-05-26 15:55:15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       3 print(type(formatted_date))
#       4 print(formatted_date)
#       5
#       6 str_datetime = "2025/12/31 23:59:59"
# ----> 7 special_datetime = datetime.strftime(str_datetime,"%Y/%m/%d %H:%M:%S")
#       8 print(type(special_datetime))
#       9 print(special_datetime)
#
# TypeError: descriptor 'strftime' for 'datetime.date' objects doesn't apply to a 'str' object
