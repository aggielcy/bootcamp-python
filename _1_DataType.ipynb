# %%
print (10 + 3)
print (10 /3.0)
# error: print(10/0)
# Out:
# 13
# 3.3333333333333335

# %%
#BigDecimanl
print (0.1 + 0.2)
print(round(0.1+0.2, 1))
# Out:
# 0.30000000000000004
# 0.3

# %%
# Data Type 
# int, float, str, boolean

x =3
print (type(x))

x=3.3
print (type(x)) #Variable Dynamic

x = "hello"
print (type(x))

x = False
print (type(x))
print(x)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# False

# %%
y ="hello"
print (y*3)

#python cannot str +other type -->error
# y = y + 2
y = y + str(2)
print (y)

y = 0.1+ 1  #float +int = float
print (type(y))

a=10
a+=1
print(a)

print (True +2) #True =1 when boolean +
print (False +2) #False 0
# Out:
# hellohellohello
# hello2
# <class 'float'>
# 11
# 3
# 2

# %%
s ="Java"
s+= "python"
print("s=" + s)

first_name ="Jason"
last_name ="wong"
print(f"His name {first_name} {last_name}")
# Out:
# s=Javapython
# His name Jason wong
