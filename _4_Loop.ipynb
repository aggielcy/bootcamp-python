# %%
names = ['John', 'Steven', 'Jennie']

for name in names:
  print(name)

for i in range(3):  # wont do this in python
  print (names[i])

for ch in "Java":
  print(ch) #str type
  print (type(ch))


word = "hello World"
#check if o exixt -->boolean
o_exist = False
for c in word:
  if(c =='o'):
    o_exist = True
    break
print(o_exist)  #<-- wont do in this one

print('o' in word)  #<-- normally do that
# Out:
# John
# Steven
# Jennie
# John
# Steven
# Jennie
# J
# <class 'str'>
# a
# <class 'str'>
# v
# <class 'str'>
# a
# <class 'str'>
# True
# True

# %%
count = 5
while (count >0):
  print (count)
  count -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
numbers = [1, 100, -6, 20000]
print(max(numbers))
print(min(numbers))
print(sum(numbers))
print(len(numbers))

# indexOf
print (numbers.index(20000)) # 3
print (numbers.index(max(numbers))) # 3

print(sum(numbers)/len(numbers))  #<--average
# Out:
# 20000
# -6
# 20095
# 4
# 3
# 3
# 5023.75

# %%
n = 4
for i in range(n):  # 1,2,3,4
  print('*' * (i + 1))
# Out:
# *
# **
# ***
# ****
