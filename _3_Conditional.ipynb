# %%
x = 10
if (x > 9):
  print(x)  

# and or (Java && ||)
if( x < 20 and x >1):
  print(x)

if(x > 0):
  print("Positive")
else:
  print("Negative")
# Out:
# 10
# 10
# Positive

# %%
score = 92
if (score >= 90):
  grade = "A"
elif (score >= 10):
  grade = "B"
else:
  grade = "F"
print(f'grade={grade}')
# Out:
# grade=A

# %%
#Java: equals
a = "hello"
b = "hello"
c = "".join(['h','e','l','l','o'])

print(type(b))
print(type(c))

print(a == b) #same value
print(a == c) #same value
print (a is b)
print (b is c) #false (not same object)
# Out:
# <class 'str'>
# <class 'str'>
# True
# True
# True
# False

# %%
# +, -, *, /, %
number = 3
if(number % 2 == 1):
  print ("Odd")
else:
  print ("Even")
# Out:
# Odd

# %%
fruit = ['apple', 'orange', 'lemon']
print(fruit)
print (type(fruit))

if (fruit[0] == 'apple'):
  print ('it is apple')
# Out:
# ['apple', 'orange', 'lemon']
# <class 'list'>
# it is apple
