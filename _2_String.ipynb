# %%
# String --> actually is char[]
word ='python'
print (word[0])
print (word [-1]) #Java length -1
print (word [-3])

print (word [:3])
print (word [1:3])
print (word [2:])

print (word.upper())
print (word.lower())
print (word.replace('t','x'))
# Out:
# p
# n
# h
# pyt
# yt
# thon
# PYTHON
# python
# pyxhon

# %%
csv_row = "apple, orange, kiwki, lemon"
result = csv_row.split(",")
print(type(result))
print (result)
# Out:
# <class 'list'>
# ['apple', ' orange', ' kiwki', ' lemon']

# %%
student_name = "Steven"
print(student_name.count('e'))
print(student_name.isalpha())
print(student_name.isdigit())
print(student_name.startswith('s'))
print(student_name.startswith('S')) #case senitive

score = "93"
print(score.isdigit())
# Out:
# 2
# True
# False
# False
# True
# True
